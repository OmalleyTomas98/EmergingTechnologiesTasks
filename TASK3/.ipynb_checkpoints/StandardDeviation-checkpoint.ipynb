# %% [markdown]
# # Galway Mayo Institute of Technology
#
# | Header | Description |
# | --- | --- |
# | `Author` | Tomas O'Malley (G00361128)@gmit.ie |
# | `Course` | Software Development GA_KSOAG_H08 Y4  |
# | `Module` | Emerging Technologies   |
# | `Task No` | 3 |
# | `Program` | Standard Deviation |
# | `Langauge` | Python |
# | `Weighting` | 50% |
# | `Year of Study` | 4 |
#
#
# # Problem Sheet
#
#
# The standard deviation of an array of numbers x is
# calculated using numpy as np.sqrt(np.sum((x - np.mean(x))**2)/len(x)) .
# However, Microsoft Excel has two different versions of the standard deviation
# calculation, STDEV.P and STDEV.S . The STDEV.P function performs the above
# calculation but in the STDEV.S calculation the division is by len(x)-1 rather
# than len(x) . Research these Excel functions, writing a note in a Markdown cell
# about the difference between them. Then use numpy to perform a simulation
# demonstrating that the STDEV.S calculation is a better estimate for the standard
# deviation of a population when performed on a sample. Note that part of this task
# is to figure out the terminology in the previous sentence
#
#
#
# # Research
#
# - What is meant by the term ' Standard Deviation ' A  quantity expressing by how much the members of a group differ from the mean value for the group.
#
# - Microsoft Excel is a spreadsheet developed by Microsoft for Windows, macOS, Android and iOS. It features calculation, graphing tools, pivot tables, and a macro programming language called Visual Basic for Applications.Why is it important we know what microsoft excel is ?
#
# - As stated in the Task Sheet Microsoft Excel uses two different versions of Standard Deviation for calcualtion which are
#     STDEV.P and STDEV.S
#
#
#  **STDEV.P** :  The STDEV. P function calculates the standard deviation for a sample set of data. Standard deviation is a measure of how much variance there is in a set of numbers compared to the average (mean) of the numbers. The STDEV. P function is meant to estimate standard deviation for an entire population. Underneath is the formula used

# %% [markdown]
# ![STDEVP.JPG](attachment:STDEVP.JPG)
#
# - Required  arguments
#     - First number or reference in the sample.
#     -  [optional] Second number or reference.
#
# The **STDEV.P** function is meant to estimate standard deviation for an entire population. If data represents a sample, use the STDEV.S function.Microsoft recommends that people use the newer STDEV.P function instead.

# %% [markdown]
# **STDEV.S** : The STDEV.S function calculates the standard deviation in a sample set of data. Standard deviation is a measure of how much variance there is in a set of numbers compared to the average (mean) of the numbers. The STDEV.S function is meant to estimate standard deviation in a sample.Underneath is the formula used

# %% [markdown]
# ![STDEVS2.JPG](attachment:STDEVS2.JPG)

# %% [markdown]
# - Formula  arguments
#     -  This is the first number argument that corresponds to a sample of the population.
#     -  This is a number argument that corresponds to a second sample of the population.

# %% [markdown]
# # Solution

# %%
#import numpy as stated in Task Brief * renamed as np for short 
# Numerical Arrays.
import numpy as np

# %%
#defining a sample  array to compare methods STDEV.P vs STDDEV.S 
x = np.array([[11, 111], [111, 333]])

# %%
# instantiate STDDEV.S function
b = np.sqrt(np.sum((x - np.mean(x))**2)/len(x)-1)
# instantiate STDDEV.P function
a = np.sqrt(np.sum((x - np.mean(x))**2)/len(x))

# %%
#print output(s)
print(a)
print(b)
# Out:
# 166.67783295927507
# 166.6748331332598

# %% [markdown]
# ***
# ### END

# %% [markdown]
# # References
#
#
# - Standard Deviation https://languages.oup.com/google-dictionary-en/
# - Microsoft Excel Description https://en.wikipedia.org/wiki/Microsoft_Excel
# - STDEV.P Forumla  https://support.microsoft.com/en-us/office/stdevp-function-1f7c1c88-1bec-4422-8242-e9f7dc8bb195
# - STDEV.S Forumla https://exceljet.net/excel-functions/excel-stdev.s-function#:~:text=The%20STDEV.,The%20STDEV.&text=If%20data%20represents%20an%20entire%20population%2C%20use%20the%20STDEV.
